# %% [markdown]
# # Import necessary modules
#
# We begin by importing all necessary modules. The install function can be used to install the uninstalled modules.

# %%
import os
import sys
root_repo = os.path.abspath(os.path.join(os.getcwd(), ".."))
if root_repo not in sys.path:
    sys.path.append(root_repo)

from src.ingest import fetch_neso_data, clean_data, get_engine, export_to_sql

# %% [markdown]
# # Import Data From UK national grid
#
# The data is from neso https://www.neso.energy/data-portal/historic-generation-mix/historic_gb_generation_mix

# %%
df = fetch_neso_data()
# Out:
# 📥 Fetching data from NESO API...
# Fetch 302112 rows

# %% [markdown]
# # Preprocess dataframe

# %%
sorted_df = clean_data(df)
# Out:
# 🧹 Cleaning data...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302112 entries, 0 to 302111
# Data columns (total 34 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   DATETIME          302112 non-null  datetime64[ns]
#  1   CARBON_INTENSITY  302112 non-null  float64
#  2   NUCLEAR           302112 non-null  float64
#  3   STORAGE           302112 non-null  float64
#  4   LOW_CARBON        302112 non-null  float64
#  5   HYDRO             302112 non-null  float64
#  6   WIND_EMB          302112 non-null  float64
#  7   IMPORTS           302112 non-null  float64
#  8   GAS               302112 non-null  float64
#  9   COAL              302112 non-null  float64
#  10  FOSSIL            302112 non-null  float64
#  11  GENERATION        302112 non-null  float64
#  12  OTHER             302112 non-null  float64
#  13  ZERO_CARBON       302112 non-null  float64
#  14  BIOMASS           302112 non-null  float64
#  15  WIND              302112 non-null  float64
#  16  SOLAR             302112 non-null  float64
#  17  RENEWABLE         302112 non-null  float64
#  18  RENEWABLE_perc    302112 non-null  float64
#  19  HYDRO_perc        302112 non-null  float64
#  20  IMPORTS_perc      302112 non-null  float64
#  21  SOLAR_perc        302112 non-null  float64
#  22  BIOMASS_perc      302112 non-null  float64
#  23  STORAGE_perc      302112 non-null  float64
#  24  WIND_perc         302112 non-null  float64
#  25  LOW_CARBON_perc   302112 non-null  float64
#  26  COAL_perc         302112 non-null  float64
#  27  ZERO_CARBON_perc  302112 non-null  float64
#  28  FOSSIL_perc       302112 non-null  float64
#  29  GENERATION_perc   302112 non-null  float64
#  30  NUCLEAR_perc      302112 non-null  float64
#  31  WIND_EMB_perc     302112 non-null  float64
#  32  GAS_perc          302112 non-null  float64
#  33  OTHER_perc        302112 non-null  float64
# dtypes: datetime64[ns](1), float64(33)
# memory usage: 78.4 MB
# None

# %% [markdown]
# # Export to SQL

# %% [markdown]
# Create engine & export to postgreSQL

# %%
engine = get_engine()
# Out:
# ['db', 'energy_forecast', 'postgres', 'password123', '5432']

# %% [markdown]
# Export with df.to_sql

# %%
# Export DataFrame to a table named "generation_data"
export_to_sql(sorted_df, engine)
# Out:
# 💾 Saving 302112 rows to database...
# Data exported to PostgreSQL successfully.
